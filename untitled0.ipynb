# %% [markdown]
# <a href="https://colab.research.google.com/github/avulasanjanareddy19-coder/DSA-Case-Studies/blob/main/untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# --- VARIABLES & TYPES ---
x = 5
y = 3.14
name = "CGPA"
is_placed = True

print(x, type(x))
print(y, type(y))
print(is_placed, type(is_placed))
# Out:
# 5 <class 'int'>
# 3.14 <class 'float'>
# True <class 'bool'>

# %%
# --- ARITHMETIC OPERATORS ---
a = 7
b = 2
print("a + b =", a + b)
print("a - b =", a - b)
print("a * b =", a * b)
print("a / b =", a / b)
print("a ** 2 =", a ** 2)

cgpa = 8.4
print("cgpa == 8.4 :", cgpa == 8.4)
print("cgpa > 8    :", cgpa > 8)
print("cgpa < 6    :", cgpa < 6)

attendence = 85
placed = (cgpa > 8) and (attendence > 80)
print("placed :", placed)
# Out:
# a + b = 9
# a - b = 5
# a * b = 14
# a / b = 3.5
# a ** 2 = 49
# cgpa == 8.4 : True
# cgpa > 8    : True
# cgpa < 6    : False
# placed : True
